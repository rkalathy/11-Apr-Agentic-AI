# %%
# !pip install agno openai ddgs yfinance
# Out:
# Requirement already satisfied: agno in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (2.6.4)
# Requirement already satisfied: openai in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (2.32.0)
# Requirement already satisfied: ddgs in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (9.14.0)
# Requirement already satisfied: yfinance in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: docstring-parser in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (0.18.0)
# Requirement already satisfied: gitpython in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (3.1.46)
# Requirement already satisfied: h11>=0.16.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (0.16.0)
# Requirement already satisfied: httpx[http2] in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (0.28.1)
# Requirement already satisfied: packaging in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (26.1)
# Requirement already satisfied: pydantic-settings in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (2.13.1)
# Requirement already satisfied: pydantic in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (2.13.2)
# Requirement already satisfied: python-dotenv in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (1.2.2)
# Requirement already satisfied: python-multipart in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (0.0.26)
# Requirement already satisfied: pyyaml in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (6.0.3)
# Requirement already satisfied: rich in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (15.0.0)
# Requirement already satisfied: typer in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (0.24.1)
# Requirement already satisfied: typing-extensions in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from agno) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from openai) (0.14.0)
# Requirement already satisfied: sniffio in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from openai) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from httpx[http2]->agno) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from httpx[http2]->agno) (1.0.9)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from pydantic->agno) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from pydantic->agno) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from pydantic->agno) (0.4.2)
# Requirement already satisfied: click>=8.1.8 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from ddgs) (8.3.2)
# Requirement already satisfied: primp>=1.2.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from ddgs) (1.2.2)
# Requirement already satisfied: lxml>=4.9.4 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from ddgs) (6.1.0)
# Requirement already satisfied: pandas>=1.3.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (6.33.6)
# Requirement already satisfied: websockets>=13.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: pycparser in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from gitpython->agno) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython->agno) (5.0.3)
# Requirement already satisfied: h2<5,>=3 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from httpx[http2]->agno) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]->agno) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]->agno) (4.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from rich->agno) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from rich->agno) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->agno) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from typer->agno) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/trainer/11 Apr Agentic AI/.venv/lib/python3.13/site-packages (from typer->agno) (0.0.4)
#
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

os.environ["OPENAI_API_KEY"] = "ADD KEY HERE"

from agno.agent import Agent
from agno.models.openai import OpenAIChat

# %%
agent = Agent(
    model=OpenAIChat(id="gpt-4o-mini"),
    instructions="You are a helpful assistant that answers questions about the stock market.",
    markdown=True,
)

response = agent.run("What is the current price of Apple stock?")

print(response.content)
# Out:
# I'm sorry, but I can't provide real-time stock prices or updates as my information is only current up to October 2023. However, you can easily find the current price of Apple stock (AAPL) by checking financial news websites, stock market apps, or your brokerage platform.
