# %%
# !pip install agno openai ddgs yfinance dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv()

from agno.agent import Agent
from agno.models.openai import OpenAIChat

# %%
agent = Agent(
    model=OpenAIChat(id="gpt-4o-mini"),
    instructions="You are a helpful assistant that answers questions about the stock market.",
    markdown=True,
)

response = agent.run("What is the current price of Apple stock?")

print(response.content)
# Out:
# I don’t have real-time data access, so I can't provide the current price of Apple stock (AAPL). To find the latest price, please check a financial news website, a stock market app, or a brokerage platform.

# %%
from agno.tools.duckduckgo import DuckDuckGoTools

agent = Agent(
    model=OpenAIChat(id="gpt-4o-mini"),
    tools=[DuckDuckGoTools()],
    instructions="You are a helpful assistant that answers questions about the stock market.",
    markdown=True,
)

response = agent.run("What is the current price of Apple stock?")

print(response.content)
# Out:
# You can check the current price of Apple stock (AAPL) through the following links:
#
# 1. [Google Finance - Apple Inc (AAPL)](https://www.google.com/finance/beta/quote/AAPL:NASDAQ)
# 2. [Investing.com - Apple Stock Price Today](https://www.investing.com/equities/apple-computer-inc)
# 3. [MarketWatch - AAPL Stock Price](https://www.marketwatch.com/investing/stock/aapl)
# 4. [CNBC - Apple Inc (AAPL)](https://www.cnbc.com/quotes/aapl)
#
# These resources provide real-time stock prices and additional financial information.

# %%
from agno.tools.yfinance import YFinanceTools

agent = Agent(
    model=OpenAIChat(id="gpt-4o-mini"),
    tools=[YFinanceTools()],
    instructions="You are a helpful assistant that answers questions about the stock market.",
    markdown=True,
)

response = agent.run("What is the current price of Apple stock?")

print(response.content)
# Out:
# The current price of Apple stock (AAPL) is **$280.14**.
